# %% [markdown]
# ## MICCAI 2015 Abdominal dataset
#
# ### Overview
#
# This is the second step of preprocessing
#
# Cut out irrelevant empty boundary and resample to 256-by-256 in axial plane.
#
# Input: intensity-normalized images
#
# Output: spacially resampled images

# %%
# %reset
# %load_ext autoreload
# %autoreload 2
import numpy as np
import os
import glob
import SimpleITK as sitk
import sys

sys.path.insert(0, '../../dataloaders/')
import niftiio as nio
from tqdm.notebook import tqdm
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
IMG_FOLDER = "/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/"
SEG_FOLDER = IMG_FOLDER
imgs = glob.glob(IMG_FOLDER + "/image_*.nii.gz")
imgs = [ fid for fid in sorted(imgs) ]
segs = [ fid for fid in sorted(glob.glob(SEG_FOLDER + "/label_*.nii.gz")) ]

pids = [pid.split("_")[-1].split(".")[0] for pid in imgs]

# %%
# helper functions copy pasted
def resample_by_res(mov_img_obj, new_spacing, interpolator = sitk.sitkLinear, logging = True):
    resample = sitk.ResampleImageFilter()
    resample.SetInterpolator(interpolator)
    resample.SetOutputDirection(mov_img_obj.GetDirection())
    resample.SetOutputOrigin(mov_img_obj.GetOrigin())
    mov_spacing = mov_img_obj.GetSpacing()

    resample.SetOutputSpacing(new_spacing)
    RES_COE = np.array(mov_spacing) * 1.0 / np.array(new_spacing)
    new_size = np.array(mov_img_obj.GetSize()) *  RES_COE 

    resample.SetSize( [int(sz+1) for sz in new_size] )
    if logging:
        print("Spacing: {} -> {}".format(mov_spacing, new_spacing))
        print("Size {} -> {}".format( mov_img_obj.GetSize(), new_size ))

    return resample.Execute(mov_img_obj)

def resample_lb_by_res(mov_lb_obj, new_spacing, interpolator = sitk.sitkLinear, ref_img = None, logging = True):
    src_mat = sitk.GetArrayFromImage(mov_lb_obj)
    lbvs = np.unique(src_mat)
    if logging:
        print("Label values: {}".format(lbvs))
    for idx, lbv in enumerate(lbvs):
        _src_curr_mat = np.float32(src_mat == lbv) 
        _src_curr_obj = sitk.GetImageFromArray(_src_curr_mat)
        _src_curr_obj.CopyInformation(mov_lb_obj)
        _tar_curr_obj = resample_by_res( _src_curr_obj, new_spacing, interpolator, logging )
        _tar_curr_mat = np.rint(sitk.GetArrayFromImage(_tar_curr_obj)) * lbv
        if idx == 0:
            out_vol = _tar_curr_mat
        else:
            out_vol[_tar_curr_mat == lbv] = lbv
    out_obj = sitk.GetImageFromArray(out_vol)
    out_obj.SetSpacing( _tar_curr_obj.GetSpacing() )
    if ref_img != None:
        out_obj.CopyInformation(ref_img)
    return out_obj
        
## Then crop ROI
def get_label_center(label):
    nnz = np.sum(label > 1e-5)
    return np.int32(np.rint(np.sum(np.nonzero(label), axis = 1) * 1.0 / nnz))

def image_crop(ori_vol, crop_size, referece_ctr_idx, padval = 0., only_2d = True):
    """ crop a 3d matrix given the index of the new volume on the original volume
        Args:
            refernce_ctr_idx: the center of the new volume on the original volume (in indices)
            only_2d: only do cropping on first two dimensions
    """
    _expand_cropsize = [x + 1 for x in crop_size] # to deal with boundary case
    if only_2d:
        assert len(crop_size) == 2, "Actual len {}".format(len(crop_size))
        assert len(referece_ctr_idx) == 2, "Actual len {}".format(len(referece_ctr_idx))
        _expand_cropsize.append(ori_vol.shape[-1])
        
    image_patch = np.ones(tuple(_expand_cropsize)) * padval

    half_size = tuple( [int(x * 1.0 / 2) for x in _expand_cropsize] )
    _min_idx = [0,0,0]
    _max_idx = list(ori_vol.shape)

    # bias of actual cropped size to the beginning and the end of this volume
    _bias_start = [0,0,0]
    _bias_end = [0,0,0]

    for dim,hsize in enumerate(half_size):
        if dim == 2 and only_2d:
            break

        _bias_start[dim] = np.min([hsize, referece_ctr_idx[dim]])
        _bias_end[dim] = np.min([hsize, ori_vol.shape[dim] - referece_ctr_idx[dim]])

        _min_idx[dim] = referece_ctr_idx[dim] - _bias_start[dim]
        _max_idx[dim] = referece_ctr_idx[dim] + _bias_end[dim]
        
    if only_2d:
        image_patch[ half_size[0] - _bias_start[0]: half_size[0] +_bias_end[0], \
                half_size[1] - _bias_start[1]: half_size[1] +_bias_end[1], ... ] = \
                ori_vol[ referece_ctr_idx[0] - _bias_start[0]: referece_ctr_idx[0] +_bias_end[0], \
                referece_ctr_idx[1] - _bias_start[1]: referece_ctr_idx[1] +_bias_end[1], ... ]

        image_patch = image_patch[ 0: crop_size[0], 0: crop_size[1], : ]
    # then goes back to original volume
    else:
        image_patch[ half_size[0] - _bias_start[0]: half_size[0] +_bias_end[0], \
                half_size[1] - _bias_start[1]: half_size[1] +_bias_end[1], \
                half_size[2] - _bias_start[2]: half_size[2] +_bias_end[2] ] = \
                ori_vol[ referece_ctr_idx[0] - _bias_start[0]: referece_ctr_idx[0] +_bias_end[0], \
                referece_ctr_idx[1] - _bias_start[1]: referece_ctr_idx[1] +_bias_end[1], \
                referece_ctr_idx[2] - _bias_start[2]: referece_ctr_idx[2] +_bias_end[2] ]

        image_patch = image_patch[ 0: crop_size[0], 0: crop_size[1], 0: crop_size[2] ]
    return image_patch

   
    
def copy_spacing_ori(src, dst):
    dst.SetSpacing(src.GetSpacing())
    dst.SetOrigin(src.GetOrigin())
    dst.SetDirection(src.GetDirection())
    return dst

# %%
imgs
# Out:
# ['/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_084.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_085.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_086.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_087.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_088.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_089.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_090.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_091.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_092.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_093.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_094.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_095.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_096.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_097.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_098.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_099.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_100.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_101.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_102.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_103.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_104.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_105.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_106.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_107.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_108.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_109.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_110.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_111.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_112.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_113.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_114.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_115.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_116.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_117.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_118.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_119.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_120.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_121.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_122.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_123.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_124.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_125.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_126.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_127.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_128.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_129.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_130.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_131.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_132.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_133.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_134.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_135.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_136.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_137.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_138.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_139.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_140.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_141.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_142.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_143.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_144.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_145.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_146.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_147.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_148.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_149.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_150.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA002.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA003.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA004.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA005.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA006.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA007.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA008.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA009.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA010.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA011.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA012.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA013.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA014.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA015.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA016.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA017.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA018.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA019.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA020.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA021.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA022.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA023.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA024.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA025.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA026.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA027.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA028.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA029.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA030.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA031.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA032.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA033.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA034.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA035.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA036.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA037.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA038.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA039.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA040.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA041.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA042.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA043.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA044.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA045.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA046.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA048.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA049.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA050.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA051.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA052.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA053.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA054.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA055.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA056.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA057.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/image_PA058.nii.gz']

# %%
segs
# Out:
# ['/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_084.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_085.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_086.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_087.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_088.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_089.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_090.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_091.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_092.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_093.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_094.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_095.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_096.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_097.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_098.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_099.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_100.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_101.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_102.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_103.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_104.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_105.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_106.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_107.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_108.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_109.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_110.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_111.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_112.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_113.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_114.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_115.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_116.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_117.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_118.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_119.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_120.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_121.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_122.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_123.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_124.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_125.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_126.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_127.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_128.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_129.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_130.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_131.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_132.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_133.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_134.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_135.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_136.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_137.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_138.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_139.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_140.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_141.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_142.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_143.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_144.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_145.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_146.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_147.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_148.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_149.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_150.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA002.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA003.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA004.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA005.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA006.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA007.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA008.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA009.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA010.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA011.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA012.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA013.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA014.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA015.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA016.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA017.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA018.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA019.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA020.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA021.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA022.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA023.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA024.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA025.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA026.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA027.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA028.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA029.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA030.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA031.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA032.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA033.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA034.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA035.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA036.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA037.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA038.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA039.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA040.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA041.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA042.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA043.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA044.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA045.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA046.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA048.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA049.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA050.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA051.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA052.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA053.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA054.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA055.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA056.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA057.nii.gz',
#  '/home/htang6/workspace/data/abdomen/superpixel/tmp_normalized/label_PA058.nii.gz']

# %%
import copy
OUT_FOLDER = "/home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized"
scan_dir = OUT_FOLDER
os.makedirs(scan_dir, exist_ok = True)
BD_BIAS = 32 # cut irrelavent empty boundary to make roi stands out

SPA_FAC = (512 - 2 * BD_BIAS) / 256 # spacing factor

for img_fid, seg_fid, pid in tqdm(zip(imgs, segs, pids), total=len(imgs)):

    lb_n = nio.read_nii_bysitk(seg_fid)

    img_obj = sitk.ReadImage( img_fid )
    seg_obj = sitk.ReadImage( seg_fid )

    ## image
    array = sitk.GetArrayFromImage(img_obj)
    # cropping
    array = array[:, BD_BIAS: -BD_BIAS, BD_BIAS: -BD_BIAS]
    cropped_img_o = sitk.GetImageFromArray(array)
    cropped_img_o = copy_spacing_ori(img_obj, cropped_img_o)

    # resampling
    img_spa_ori = img_obj.GetSpacing()
    res_img_o = resample_by_res(cropped_img_o, [img_spa_ori[0] * SPA_FAC, img_spa_ori[1] * SPA_FAC, img_spa_ori[-1]], interpolator = sitk.sitkLinear,
                                    logging = True)

    ## label
    lb_arr = sitk.GetArrayFromImage(seg_obj)
    
    # cropping
    lb_arr = lb_arr[:,BD_BIAS: -BD_BIAS, BD_BIAS: -BD_BIAS]
    cropped_lb_o = sitk.GetImageFromArray(lb_arr)
    cropped_lb_o = copy_spacing_ori(seg_obj, cropped_lb_o)

    lb_spa_ori = seg_obj.GetSpacing()

    # resampling
    res_lb_o = resample_lb_by_res(cropped_lb_o,  [lb_spa_ori[0] * SPA_FAC, lb_spa_ori[1] * SPA_FAC, lb_spa_ori[-1] ], interpolator = sitk.sitkLinear,
                                  ref_img = res_img_o, logging = True)

    
    out_img_fid = os.path.join( scan_dir, f'image_{pid}.nii.gz' )
    out_lb_fid  = os.path.join( scan_dir, f'label_{pid}.nii.gz' ) 
    
    # then save
    sitk.WriteImage(res_img_o, out_img_fid, True) 
    sitk.WriteImage(res_lb_o, out_lb_fid, True) 
    print("{} has been saved".format(out_img_fid))
    print("{} has been saved".format(out_lb_fid))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=123.0), HTML(value='')))
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 208) -> [256. 256. 208.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 208) -> [256. 256. 208.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 208) -> [256. 256. 208.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 208) -> [256. 256. 208.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 208) -> [256. 256. 208.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 208) -> [256. 256. 208.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_084.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_084.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 213) -> [256. 256. 213.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 213) -> [256. 256. 213.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 213) -> [256. 256. 213.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 213) -> [256. 256. 213.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 213) -> [256. 256. 213.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 213) -> [256. 256. 213.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_085.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_085.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 267) -> [256. 256. 267.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 267) -> [256. 256. 267.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 267) -> [256. 256. 267.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 267) -> [256. 256. 267.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 267) -> [256. 256. 267.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 267) -> [256. 256. 267.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_086.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_086.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 219) -> [256. 256. 219.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 219) -> [256. 256. 219.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 219) -> [256. 256. 219.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 219) -> [256. 256. 219.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 219) -> [256. 256. 219.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 219) -> [256. 256. 219.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_087.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_087.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 203) -> [256. 256. 203.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 203) -> [256. 256. 203.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 203) -> [256. 256. 203.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 203) -> [256. 256. 203.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 203) -> [256. 256. 203.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 203) -> [256. 256. 203.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_088.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_088.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 195) -> [256. 256. 195.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 195) -> [256. 256. 195.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 195) -> [256. 256. 195.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 195) -> [256. 256. 195.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 195) -> [256. 256. 195.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 195) -> [256. 256. 195.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_089.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_089.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 280) -> [256. 256. 280.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 280) -> [256. 256. 280.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 280) -> [256. 256. 280.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 280) -> [256. 256. 280.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 280) -> [256. 256. 280.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 280) -> [256. 256. 280.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_090.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_090.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 273) -> [256. 256. 273.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 273) -> [256. 256. 273.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 273) -> [256. 256. 273.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 273) -> [256. 256. 273.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 273) -> [256. 256. 273.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 273) -> [256. 256. 273.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_091.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_091.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 217) -> [256. 256. 217.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 217) -> [256. 256. 217.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 217) -> [256. 256. 217.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 217) -> [256. 256. 217.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 217) -> [256. 256. 217.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 217) -> [256. 256. 217.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_092.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_092.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 267) -> [256. 256. 267.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 267) -> [256. 256. 267.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 267) -> [256. 256. 267.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 267) -> [256. 256. 267.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 267) -> [256. 256. 267.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 267) -> [256. 256. 267.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_093.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_093.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 260) -> [256. 256. 260.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 260) -> [256. 256. 260.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 260) -> [256. 256. 260.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 260) -> [256. 256. 260.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 260) -> [256. 256. 260.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 260) -> [256. 256. 260.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_094.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_094.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 211) -> [256. 256. 211.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 211) -> [256. 256. 211.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 211) -> [256. 256. 211.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 211) -> [256. 256. 211.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 211) -> [256. 256. 211.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 211) -> [256. 256. 211.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_095.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_095.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 260) -> [256. 256. 260.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 260) -> [256. 256. 260.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 260) -> [256. 256. 260.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 260) -> [256. 256. 260.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 260) -> [256. 256. 260.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 260) -> [256. 256. 260.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_096.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_096.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 195) -> [256. 256. 195.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 195) -> [256. 256. 195.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 195) -> [256. 256. 195.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 195) -> [256. 256. 195.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 195) -> [256. 256. 195.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 195) -> [256. 256. 195.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_097.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_097.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 267) -> [256. 256. 267.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 267) -> [256. 256. 267.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 267) -> [256. 256. 267.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 267) -> [256. 256. 267.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 267) -> [256. 256. 267.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 267) -> [256. 256. 267.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_098.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_098.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 263) -> [256. 256. 263.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 263) -> [256. 256. 263.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 263) -> [256. 256. 263.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 263) -> [256. 256. 263.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 263) -> [256. 256. 263.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 263) -> [256. 256. 263.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_099.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_099.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 204) -> [256. 256. 204.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 204) -> [256. 256. 204.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 204) -> [256. 256. 204.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 204) -> [256. 256. 204.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 204) -> [256. 256. 204.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 204) -> [256. 256. 204.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_100.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_100.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 223) -> [256. 256. 223.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 223) -> [256. 256. 223.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 223) -> [256. 256. 223.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 223) -> [256. 256. 223.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 223) -> [256. 256. 223.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 223) -> [256. 256. 223.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_101.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_101.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 242) -> [256. 256. 242.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 242) -> [256. 256. 242.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 242) -> [256. 256. 242.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 242) -> [256. 256. 242.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 242) -> [256. 256. 242.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 242) -> [256. 256. 242.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_102.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_102.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 258) -> [256. 256. 258.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 258) -> [256. 256. 258.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 258) -> [256. 256. 258.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 258) -> [256. 256. 258.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 258) -> [256. 256. 258.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 258) -> [256. 256. 258.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_103.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_103.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 221) -> [256. 256. 221.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 221) -> [256. 256. 221.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 221) -> [256. 256. 221.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 221) -> [256. 256. 221.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 221) -> [256. 256. 221.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 221) -> [256. 256. 221.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_104.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_104.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 192) -> [256. 256. 192.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 192) -> [256. 256. 192.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 192) -> [256. 256. 192.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 192) -> [256. 256. 192.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 192) -> [256. 256. 192.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 192) -> [256. 256. 192.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_105.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_105.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 194) -> [256. 256. 194.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 194) -> [256. 256. 194.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 194) -> [256. 256. 194.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 194) -> [256. 256. 194.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 194) -> [256. 256. 194.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 194) -> [256. 256. 194.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_106.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_106.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 200) -> [256. 256. 200.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 200) -> [256. 256. 200.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 200) -> [256. 256. 200.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 200) -> [256. 256. 200.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 200) -> [256. 256. 200.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 200) -> [256. 256. 200.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_107.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_107.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 191) -> [256. 256. 191.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 191) -> [256. 256. 191.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 191) -> [256. 256. 191.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 191) -> [256. 256. 191.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 191) -> [256. 256. 191.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 191) -> [256. 256. 191.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_108.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_108.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 185) -> [256. 256. 185.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 185) -> [256. 256. 185.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 185) -> [256. 256. 185.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 185) -> [256. 256. 185.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 185) -> [256. 256. 185.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 185) -> [256. 256. 185.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_109.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_109.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 190) -> [256. 256. 190.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 190) -> [256. 256. 190.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 190) -> [256. 256. 190.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 190) -> [256. 256. 190.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 190) -> [256. 256. 190.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 190) -> [256. 256. 190.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_110.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_110.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 185) -> [256. 256. 185.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 185) -> [256. 256. 185.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 185) -> [256. 256. 185.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 185) -> [256. 256. 185.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 185) -> [256. 256. 185.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 185) -> [256. 256. 185.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_111.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_111.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 176) -> [256. 256. 176.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 176) -> [256. 256. 176.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 176) -> [256. 256. 176.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 176) -> [256. 256. 176.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 176) -> [256. 256. 176.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 176) -> [256. 256. 176.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_112.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_112.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 277) -> [256. 256. 277.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 277) -> [256. 256. 277.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 277) -> [256. 256. 277.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 277) -> [256. 256. 277.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 277) -> [256. 256. 277.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 277) -> [256. 256. 277.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_113.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_113.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 214) -> [256. 256. 214.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 214) -> [256. 256. 214.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 214) -> [256. 256. 214.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 214) -> [256. 256. 214.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 214) -> [256. 256. 214.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 214) -> [256. 256. 214.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_114.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_114.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 176) -> [256. 256. 176.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 176) -> [256. 256. 176.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 176) -> [256. 256. 176.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 176) -> [256. 256. 176.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 176) -> [256. 256. 176.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 176) -> [256. 256. 176.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_115.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_115.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 200) -> [256. 256. 200.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 200) -> [256. 256. 200.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 200) -> [256. 256. 200.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 200) -> [256. 256. 200.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 200) -> [256. 256. 200.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 200) -> [256. 256. 200.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_116.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_116.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 203) -> [256. 256. 203.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 203) -> [256. 256. 203.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 203) -> [256. 256. 203.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 203) -> [256. 256. 203.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 203) -> [256. 256. 203.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 203) -> [256. 256. 203.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_117.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_117.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 188) -> [256. 256. 188.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 188) -> [256. 256. 188.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 188) -> [256. 256. 188.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 188) -> [256. 256. 188.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 188) -> [256. 256. 188.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 188) -> [256. 256. 188.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_118.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_118.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 244) -> [256. 256. 244.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 244) -> [256. 256. 244.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 244) -> [256. 256. 244.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 244) -> [256. 256. 244.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 244) -> [256. 256. 244.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 244) -> [256. 256. 244.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_119.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_119.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 177) -> [256. 256. 177.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 177) -> [256. 256. 177.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 177) -> [256. 256. 177.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 177) -> [256. 256. 177.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 177) -> [256. 256. 177.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 177) -> [256. 256. 177.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_120.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_120.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 213) -> [256. 256. 213.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 213) -> [256. 256. 213.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 213) -> [256. 256. 213.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 213) -> [256. 256. 213.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 213) -> [256. 256. 213.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 213) -> [256. 256. 213.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_121.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_121.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 258) -> [256. 256. 258.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 258) -> [256. 256. 258.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 258) -> [256. 256. 258.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 258) -> [256. 256. 258.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 258) -> [256. 256. 258.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 258) -> [256. 256. 258.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_122.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_122.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 257) -> [256. 256. 257.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 257) -> [256. 256. 257.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 257) -> [256. 256. 257.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 257) -> [256. 256. 257.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 257) -> [256. 256. 257.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 257) -> [256. 256. 257.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_123.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_123.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 199) -> [256. 256. 199.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 199) -> [256. 256. 199.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 199) -> [256. 256. 199.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 199) -> [256. 256. 199.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 199) -> [256. 256. 199.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 199) -> [256. 256. 199.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_124.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_124.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 266) -> [256. 256. 266.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 266) -> [256. 256. 266.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 266) -> [256. 256. 266.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 266) -> [256. 256. 266.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 266) -> [256. 256. 266.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 266) -> [256. 256. 266.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_125.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_125.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 229) -> [256. 256. 229.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 229) -> [256. 256. 229.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 229) -> [256. 256. 229.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 229) -> [256. 256. 229.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 229) -> [256. 256. 229.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 229) -> [256. 256. 229.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_126.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_126.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 197) -> [256. 256. 197.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 197) -> [256. 256. 197.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 197) -> [256. 256. 197.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 197) -> [256. 256. 197.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 197) -> [256. 256. 197.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 197) -> [256. 256. 197.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_127.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_127.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 204) -> [256. 256. 204.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 204) -> [256. 256. 204.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 204) -> [256. 256. 204.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 204) -> [256. 256. 204.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 204) -> [256. 256. 204.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 204) -> [256. 256. 204.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_128.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_128.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 235) -> [256. 256. 235.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 235) -> [256. 256. 235.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 235) -> [256. 256. 235.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 235) -> [256. 256. 235.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 235) -> [256. 256. 235.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 235) -> [256. 256. 235.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_129.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_129.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 212) -> [256. 256. 212.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 212) -> [256. 256. 212.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 212) -> [256. 256. 212.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 212) -> [256. 256. 212.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 212) -> [256. 256. 212.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 212) -> [256. 256. 212.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_130.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_130.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 219) -> [256. 256. 219.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 219) -> [256. 256. 219.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 219) -> [256. 256. 219.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 219) -> [256. 256. 219.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 219) -> [256. 256. 219.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 219) -> [256. 256. 219.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_131.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_131.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 242) -> [256. 256. 242.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 242) -> [256. 256. 242.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 242) -> [256. 256. 242.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 242) -> [256. 256. 242.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 242) -> [256. 256. 242.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 242) -> [256. 256. 242.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_132.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_132.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 251) -> [256. 256. 251.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 251) -> [256. 256. 251.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 251) -> [256. 256. 251.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 251) -> [256. 256. 251.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 251) -> [256. 256. 251.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 251) -> [256. 256. 251.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_133.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_133.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 229) -> [256. 256. 229.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 229) -> [256. 256. 229.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 229) -> [256. 256. 229.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 229) -> [256. 256. 229.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 229) -> [256. 256. 229.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 229) -> [256. 256. 229.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_134.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_134.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 201) -> [256. 256. 201.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 201) -> [256. 256. 201.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 201) -> [256. 256. 201.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 201) -> [256. 256. 201.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 201) -> [256. 256. 201.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 201) -> [256. 256. 201.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_135.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_135.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 197) -> [256. 256. 197.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 197) -> [256. 256. 197.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 197) -> [256. 256. 197.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 197) -> [256. 256. 197.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 197) -> [256. 256. 197.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 197) -> [256. 256. 197.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_136.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_136.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 201) -> [256. 256. 201.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 201) -> [256. 256. 201.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 201) -> [256. 256. 201.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 201) -> [256. 256. 201.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 201) -> [256. 256. 201.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 201) -> [256. 256. 201.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_137.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_137.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 195) -> [256. 256. 195.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 195) -> [256. 256. 195.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 195) -> [256. 256. 195.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 195) -> [256. 256. 195.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 195) -> [256. 256. 195.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 195) -> [256. 256. 195.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_138.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_138.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 239) -> [256. 256. 239.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 239) -> [256. 256. 239.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 239) -> [256. 256. 239.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 239) -> [256. 256. 239.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 239) -> [256. 256. 239.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 239) -> [256. 256. 239.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_139.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_139.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 214) -> [256. 256. 214.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 214) -> [256. 256. 214.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 214) -> [256. 256. 214.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 214) -> [256. 256. 214.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 214) -> [256. 256. 214.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 214) -> [256. 256. 214.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_140.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_140.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 276) -> [256. 256. 276.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 276) -> [256. 256. 276.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 276) -> [256. 256. 276.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 276) -> [256. 256. 276.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 276) -> [256. 256. 276.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 276) -> [256. 256. 276.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_141.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_141.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 287) -> [256. 256. 287.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 287) -> [256. 256. 287.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 287) -> [256. 256. 287.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 287) -> [256. 256. 287.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 287) -> [256. 256. 287.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 287) -> [256. 256. 287.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_142.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_142.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 267) -> [256. 256. 267.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 267) -> [256. 256. 267.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 267) -> [256. 256. 267.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 267) -> [256. 256. 267.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 267) -> [256. 256. 267.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 267) -> [256. 256. 267.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_143.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_143.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 260) -> [256. 256. 260.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 260) -> [256. 256. 260.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 260) -> [256. 256. 260.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 260) -> [256. 256. 260.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 260) -> [256. 256. 260.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 260) -> [256. 256. 260.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_144.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_144.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 212) -> [256. 256. 212.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 212) -> [256. 256. 212.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 212) -> [256. 256. 212.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 212) -> [256. 256. 212.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 212) -> [256. 256. 212.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 212) -> [256. 256. 212.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_145.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_145.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 227) -> [256. 256. 227.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 227) -> [256. 256. 227.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 227) -> [256. 256. 227.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 227) -> [256. 256. 227.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 227) -> [256. 256. 227.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 227) -> [256. 256. 227.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_146.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_146.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 257) -> [256. 256. 257.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 257) -> [256. 256. 257.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 257) -> [256. 256. 257.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 257) -> [256. 256. 257.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 257) -> [256. 256. 257.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 257) -> [256. 256. 257.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_147.nii.gz has been saved
# ...
# Size (448, 448, 250) -> [256. 256. 250.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_PA036.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_PA036.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 225) -> [256. 256. 225.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 225) -> [256. 256. 225.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 225) -> [256. 256. 225.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 225) -> [256. 256. 225.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 225) -> [256. 256. 225.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 225) -> [256. 256. 225.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_PA037.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_PA037.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 239) -> [256. 256. 239.]
# Label values: [0. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 239) -> [256. 256. 239.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 239) -> [256. 256. 239.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 239) -> [256. 256. 239.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 239) -> [256. 256. 239.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_PA038.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_PA038.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 240) -> [256. 256. 240.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 240) -> [256. 256. 240.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 240) -> [256. 256. 240.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 240) -> [256. 256. 240.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 240) -> [256. 256. 240.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 240) -> [256. 256. 240.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_PA039.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_PA039.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 155) -> [256. 256. 155.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 155) -> [256. 256. 155.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 155) -> [256. 256. 155.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 155) -> [256. 256. 155.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 155) -> [256. 256. 155.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 155) -> [256. 256. 155.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_PA040.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_PA040.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 264) -> [256. 256. 264.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 264) -> [256. 256. 264.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 264) -> [256. 256. 264.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 264) -> [256. 256. 264.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 264) -> [256. 256. 264.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 264) -> [256. 256. 264.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_PA041.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_PA041.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 175) -> [256. 256. 175.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 175) -> [256. 256. 175.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 175) -> [256. 256. 175.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 175) -> [256. 256. 175.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 175) -> [256. 256. 175.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 175) -> [256. 256. 175.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_PA042.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_PA042.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 236) -> [256. 256. 236.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 236) -> [256. 256. 236.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 236) -> [256. 256. 236.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 236) -> [256. 256. 236.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 236) -> [256. 256. 236.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 236) -> [256. 256. 236.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_PA043.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_PA043.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 126) -> [256. 256. 126.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 126) -> [256. 256. 126.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 126) -> [256. 256. 126.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 126) -> [256. 256. 126.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 126) -> [256. 256. 126.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 126) -> [256. 256. 126.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_PA044.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_PA044.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 197) -> [256. 256. 197.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 197) -> [256. 256. 197.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 197) -> [256. 256. 197.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 197) -> [256. 256. 197.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 197) -> [256. 256. 197.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 197) -> [256. 256. 197.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_PA045.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_PA045.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 177) -> [256. 256. 177.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 177) -> [256. 256. 177.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 177) -> [256. 256. 177.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 177) -> [256. 256. 177.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 177) -> [256. 256. 177.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 177) -> [256. 256. 177.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_PA046.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_PA046.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 157) -> [256. 256. 157.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 157) -> [256. 256. 157.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 157) -> [256. 256. 157.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 157) -> [256. 256. 157.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 157) -> [256. 256. 157.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 157) -> [256. 256. 157.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_PA048.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_PA048.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 227) -> [256. 256. 227.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 227) -> [256. 256. 227.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 227) -> [256. 256. 227.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 227) -> [256. 256. 227.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 227) -> [256. 256. 227.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 227) -> [256. 256. 227.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_PA049.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_PA049.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 222) -> [256. 256. 222.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 222) -> [256. 256. 222.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 222) -> [256. 256. 222.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 222) -> [256. 256. 222.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 222) -> [256. 256. 222.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 222) -> [256. 256. 222.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_PA050.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_PA050.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 219) -> [256. 256. 219.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 219) -> [256. 256. 219.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 219) -> [256. 256. 219.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 219) -> [256. 256. 219.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 219) -> [256. 256. 219.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 219) -> [256. 256. 219.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_PA051.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_PA051.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 237) -> [256. 256. 237.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 237) -> [256. 256. 237.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 237) -> [256. 256. 237.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 237) -> [256. 256. 237.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 237) -> [256. 256. 237.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 237) -> [256. 256. 237.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_PA052.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_PA052.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 264) -> [256. 256. 264.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 264) -> [256. 256. 264.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 264) -> [256. 256. 264.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 264) -> [256. 256. 264.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 264) -> [256. 256. 264.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 264) -> [256. 256. 264.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_PA053.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_PA053.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 256) -> [256. 256. 256.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 256) -> [256. 256. 256.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 256) -> [256. 256. 256.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 256) -> [256. 256. 256.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 256) -> [256. 256. 256.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 256) -> [256. 256. 256.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_PA054.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_PA054.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 184) -> [256. 256. 184.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 184) -> [256. 256. 184.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 184) -> [256. 256. 184.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 184) -> [256. 256. 184.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 184) -> [256. 256. 184.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 184) -> [256. 256. 184.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_PA055.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_PA055.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 223) -> [256. 256. 223.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 223) -> [256. 256. 223.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 223) -> [256. 256. 223.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 223) -> [256. 256. 223.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 223) -> [256. 256. 223.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 223) -> [256. 256. 223.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_PA056.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_PA056.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 285) -> [256. 256. 285.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 285) -> [256. 256. 285.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 285) -> [256. 256. 285.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 285) -> [256. 256. 285.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 285) -> [256. 256. 285.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 285) -> [256. 256. 285.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_PA057.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_PA057.nii.gz has been saved
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 238) -> [256. 256. 238.]
# Label values: [0. 1. 2. 3. 6.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 238) -> [256. 256. 238.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 238) -> [256. 256. 238.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 238) -> [256. 256. 238.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 238) -> [256. 256. 238.]
# Spacing: (1.0, 1.0, 1.0) -> [1.75, 1.75, 1.0]
# Size (448, 448, 238) -> [256. 256. 238.]
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/image_PA058.nii.gz has been saved
# /home/htang6/workspace/data/abdomen/superpixel/sabs_CT_normalized/label_PA058.nii.gz has been saved
